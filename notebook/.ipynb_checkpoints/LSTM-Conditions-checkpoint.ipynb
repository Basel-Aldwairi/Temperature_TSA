# %%
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sys
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# 2025-12-28 13:25:02.059637: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-28 13:25:02.167733: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-28 13:25:04.250608: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /home/tripwireguy/PycharmProjects/Jordan_2018_car_accidents_weather/.venv/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
data_path = '../data/preprocessed_data_2010_2025.csv'

# %%
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#               Datetime  Temperature  Wind Speed  Condition_Blowing Sand  \
# 0  2010-01-01 00:00:00    10.000000         7.0                   False
# 1  2010-01-01 01:00:00    10.000000         6.0                   False
# 2  2010-01-01 02:00:00    10.000000         7.0                   False
# 3  2010-01-01 03:00:00    10.000000         7.0                   False
# 4  2010-01-01 04:00:00    11.111111         7.0                   False
#
#    Condition_Cloudy  Condition_Drizzle  Condition_Duststorm  Condition_Fair  \
# 0             False              False                False            True
# 1             False              False                False            True
# 2             False              False                False            True
# 3             False              False                False            True
# 4             False              False                False            True
#
#    Condition_Fog  Condition_Freezing Rain  ...  Condition_Small Hail  \
# 0          False                    False  ...                 False
# 1          False                    False  ...                 False
# 2          False                    False  ...                 False
# 3          False                    False  ...                 False
# 4          False                    False  ...                 False
#
#    Condition_Smoke  Condition_Snow  Condition_Snow Grains  Condition_Squalls  \
# 0            False           False                  False              False
# 1            False           False                  False              False
# 2            False           False                  False              False
# 3            False           False                  False              False
# 4            False           False                  False              False
#
#    Condition_Thunder  Condition_Widespread Dust  Condition_Wintry Mix  \
# 0              False                      False                 False
# 1              False                      False                 False
# 2              False                      False                 False
# 3              False                      False                 False
# 4              False                      False                 False
#
#    WindDir_sin   WindDir_cos
# 0    -0.866025 -4.999999e-01
# 1    -1.000000  1.192488e-08
# 2    -0.939693 -3.420201e-01
# 3    -0.939693 -3.420201e-01
# 4    -0.939693 -3.420201e-01
#
# [5 rows x 37 columns]

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])
df = df.sort_values('Datetime')
df = df.set_index('Datetime')

# %%
target = 'Temperature'
features = ['Temperature', 'Wind Speed', 'WindDir_sin','WindDir_cos']

# %%
split_date = '2022-1-1'
train_df = df.loc[:split_date]
test_df = df.loc[split_date:]

# %%
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()

# %%
X_train = X_scaler.fit_transform(train_df[features])
X_test = X_scaler.transform(test_df[features])

# %%
y_train = y_scaler.fit_transform(train_df[[target]])
y_test = y_scaler.transform(test_df[[target]])

# %%
WINDOW = 24

# %%
def make_sequence(X, y, window=24):
    X_seq, y_seq = [], []
    for i in range(len(X) - window):
        X_seq.append(X[i:i+window])
        y_seq.append(y[i+window])

    return np.array(X_seq), np.array(y_seq)

# %%
X_train_seq, y_train_seq = make_sequence(X_train, y_train, window=WINDOW)

# %%
X_test_seq, y_test_seq = make_sequence(X_test, y_test, window=WINDOW)

# %%
model = Sequential([
    Input(shape=(X_test_seq.shape[1],X_test_seq.shape[2])),
    LSTM(64,activation='tanh'),
    Dense(1, activation='linear')
])

# %%
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# %%
model_checkpoint = ModelCheckpoint(
    '../models/rnn_best_model_full.keras',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False
)

# %%
model.fit(X_train_seq,
          y_train_seq,
         validation_split=0.1,
         epochs=25,
         batch_size=32,
         callbacks=[model_checkpoint, early_stopping])
# Out:
# Epoch 1/25
# 2025-12-28 13:25:08.964154: I external/local_xla/xla/service/service.cc:163] XLA service 0x72ea7c00a200 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-12-28 13:25:08.964178: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): Host, Default Version
# 2025-12-28 13:25:09.009349: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#   34/2931 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 0.1510 - mae: 0.3022
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1766917509.487297   13442 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0022 - mae: 0.0300 - val_loss: 0.0010 - val_mae: 0.0257
# Epoch 2/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - loss: 5.9368e-04 - mae: 0.0183 - val_loss: 5.7357e-04 - val_mae: 0.0181
# Epoch 3/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 5.3861e-04 - mae: 0.0172 - val_loss: 4.9501e-04 - val_mae: 0.0162
# Epoch 4/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 5.1654e-04 - mae: 0.0167 - val_loss: 9.1727e-04 - val_mae: 0.0238
# Epoch 5/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - loss: 5.0060e-04 - mae: 0.0164 - val_loss: 4.9036e-04 - val_mae: 0.0165
# Epoch 6/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - loss: 4.8629e-04 - mae: 0.0162 - val_loss: 4.5731e-04 - val_mae: 0.0157
# Epoch 7/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - loss: 4.7872e-04 - mae: 0.0160 - val_loss: 4.8002e-04 - val_mae: 0.0160
# Epoch 8/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 4.7306e-04 - mae: 0.0159 - val_loss: 4.5339e-04 - val_mae: 0.0156
# Epoch 9/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - loss: 4.6894e-04 - mae: 0.0158 - val_loss: 4.6799e-04 - val_mae: 0.0158
# Epoch 10/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - loss: 4.6178e-04 - mae: 0.0157 - val_loss: 4.4904e-04 - val_mae: 0.0152
# Epoch 11/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 4.6086e-04 - mae: 0.0156 - val_loss: 4.4589e-04 - val_mae: 0.0156
# Epoch 12/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - loss: 4.5800e-04 - mae: 0.0156 - val_loss: 4.7798e-04 - val_mae: 0.0164
# Epoch 13/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 4.5211e-04 - mae: 0.0155 - val_loss: 4.4469e-04 - val_mae: 0.0152
# Epoch 14/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - loss: 4.5538e-04 - mae: 0.0156 - val_loss: 4.7731e-04 - val_mae: 0.0158
# Epoch 15/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - loss: 4.5029e-04 - mae: 0.0155 - val_loss: 4.2856e-04 - val_mae: 0.0149
# Epoch 16/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - loss: 4.4806e-04 - mae: 0.0154 - val_loss: 4.3432e-04 - val_mae: 0.0150
# Epoch 17/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - loss: 4.4378e-04 - mae: 0.0153 - val_loss: 4.3487e-04 - val_mae: 0.0149
# Epoch 18/25
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - loss: 4.4407e-04 - mae: 0.0153 - val_loss: 4.3864e-04 - val_mae: 0.0151

# %%
y_pred_scaled = model.predict(X_test_seq)
# Out:
# 1089/1089 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step

# %%
y_pred = y_scaler.inverse_transform(y_pred_scaled)
y_true = y_scaler.inverse_transform(y_test_seq)

# %%
mae = mean_absolute_error(y_true,y_pred)

# %%
mse = mean_squared_error(y_true,y_pred)

# %%
print(f'{mae= :.3f} , {mse= :.3f}')
# Out:
# mae= 0.666 , mse= 0.817

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(y_true[-200:], label='True')
ax.plot(y_pred[-200:], label='Predicted')
plt.legend()
plt.show()
