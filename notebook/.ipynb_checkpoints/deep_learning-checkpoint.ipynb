# %%
import torch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, RNN
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import pandas as pd
from datetime import datetime
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../data/scraped_weather_2010_2025.csv',index_col=0)

# %%
df.head()

# %%
df_dic = df.loc[0]

# %%
df_dic

# %%
df_temps = df_dic['Temperature'][1:-1].split()

# %%
def fix_len(index):

# %%
def get_datetime_data(index):
    date_string = df.loc[index]['Date']
    hourly_temp = df.loc[index]['Temperature'][1:-1].split()
    hourly_condition = df.loc[index]['Condition'][1:-1].replace('\'', '').split()
    hourly_wind_dir = df.loc[index]['Wind Direction'][1:-1].split()
    hourly_wind_spd = df.loc[index]['Wind Speed'][1:-1].split()

    MIN_READINGS = 20
    DAY_HOURS = 24
    num_readings = len(hourly_temp)
    
    if num_readings > DAY_HOURS:
        hourly_temp = hourly_temp[:DAY_HOURS]
        hourly_condition = hourly_condition[:DAY_HOURS]
        hourly_wind_dir = hourly_wind_dir[:DAY_HOURS]
        hourly_wind_spd = hourly_wind_spd[:DAY_HOURS]

    # print(num_readings)
    if num_readings < MIN_READINGS:
       return {
        'Datetime' : [None for _ in range(DAY_HOURS)],
        'Temperature' : [None for _ in range(DAY_HOURS)],
        'Condiction' : [None for _ in range(DAY_HOURS)],
        'Wind Direction' : [None for _ in range(DAY_HOURS)],
        'Wind Speed' : [None for _ in range(DAY_HOURS)],
    }
        

    if num_readings < DAY_HOURS:
        for _ in range(num_readings, DAY_HOURS):
            hourly_temp.append(hourly_temp[-1])
            hourly_condition.append(hourly_condition[-1])
            hourly_wind_dir.append(hourly_wind_dir[-1])
            hourly_wind_spd.append(hourly_wind_spd[-1])

    
    
    dt_list = []
    for hour in range(len(hourly_temp)):
        dt = datetime.strptime(f'{date_string} {hour}', '%Y%m%d %H')
        dt_list.append(dt) 

    hourly_temp_np = np.array(hourly_temp, np.float32)
    hourly_wind_dir_np = np.array(hourly_wind_dir, np.float32)
    hourly_wind_spd_np = np.array(hourly_wind_spd, np.float32)

    
    dic = {
        'Datetime' : dt_list,
        'Temperature' : hourly_temp_np,
        'Condiction' : hourly_condition,
        'Wind Direction' : hourly_wind_dir_np,
        'Wind Speed' : hourly_wind_spd_np,
    }

    return dic

# %%
data_datetime = []

for day in range(len(df)):
    try:
        data = get_datetime_data(day)
        data_datetime.append(data)
    except Exception as e:
        print(day)
        print(e)

# %%
df2 = pd.DataFrame(data_datetime)

# %%
df2.head()
# Out:
#                                             Datetime  ...                                         Wind Speed
# 0  [2010-01-01 00:00:00, 2010-01-01 01:00:00, 201...  ...  [7.0, 6.0, 7.0, 7.0, 7.0, 9.0, 9.0, 9.0, 9.0, ...
# 1  [2010-01-02 00:00:00, 2010-01-02 01:00:00, 201...  ...  [6.0, 6.0, 3.0, 5.0, 6.0, 3.0, 5.0, 5.0, 5.0, ...
# 2  [2010-01-03 00:00:00, 2010-01-03 01:00:00, 201...  ...  [5.0, 5.0, 0.0, 0.0, 0.0, 5.0, 5.0, 6.0, 5.0, ...
# 3  [2010-01-04 00:00:00, 2010-01-04 01:00:00, 201...  ...  [9.0, 5.0, 3.0, 3.0, 5.0, 5.0, 8.0, 8.0, 9.0, ...
# 4  [2010-01-05 00:00:00, 2010-01-05 01:00:00, 201...  ...  [5.0, 5.0, 7.0, 10.0, 7.0, 5.0, 5.0, 7.0, 5.0,...
#
# [5 rows x 5 columns]

# %%
df2.isnu

# %%
t_test = df.loc[120]['Temperature'][1:-1].strip().replace('\n','').split()

# %%
d = get_datetime_data(120)
# Out:
# 17
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 d = get_datetime_data(120)
#
# Cell In[173], line 21, in get_datetime_data(index)
#      18 print(num_readings)
#      19 if num_readings < MIN_READINGS:
#      20    return {
# ---> 21     'Datetime' : dt_list,
#      22     'Temperature' : [None for _ in range(DAY_HOURS)],
#      23     'Condiction' : [None for _ in range(DAY_HOURS)],
#      24     'Wind Direction' : [None for _ in range(DAY_HOURS)],
#      25     'Wind Speed' : [None for _ in range(DAY_HOURS)],
#      26 }
#      29 if num_readings < DAY_HOURS:
#      30     for _ in range(num_readings, DAY_HOURS):
#
# UnboundLocalError: cannot access local variable 'dt_list' where it is not associated with a value

# %%
len(t_test)
# Out:
# 17

# %%
t_test = df.loc[4784]['Temperature'][1:-1].strip().replace('\n','').split()

# %%
plt.plot(range(len(t_test)), t_test)

# %%
len(df)
# Out:
# 5838

# %%
lengths = []
for day in range(len(df)):
    l = len(df.loc[day]['Temperature'][1:-1].strip().replace('\n','').split())
    lengths.append(l)

# %%
outliers = [i for i in lengths if i != 24]

# %%
plt.hist(outliers,bins= 36)
# Out:
# (array([  4.,   2.,   2.,   0.,   1.,   1.,   3.,   1.,   1.,   4.,   1.,
#           0.,   1.,   2.,   1.,   4.,   9.,   8.,  29.,  83., 264., 952.,
#           0.,   0., 576., 175.,  67.,  24.,  13.,   1.,   3.,   1.,   0.,
#           0.,   4.,   1.]),
#  array([ 3.        ,  3.91666667,  4.83333333,  5.75      ,  6.66666667,
#          7.58333333,  8.5       ,  9.41666667, 10.33333333, 11.25      ,
#         12.16666667, 13.08333333, 14.        , 14.91666667, 15.83333333,
#         16.75      , 17.66666667, 18.58333333, 19.5       , 20.41666667,
#         21.33333333, 22.25      , 23.16666667, 24.08333333, 25.        ,
#         25.91666667, 26.83333333, 27.75      , 28.66666667, 29.58333333,
#         30.5       , 31.41666667, 32.33333333, 33.25      , 34.16666667,
#         35.08333333, 36.        ]),
#  <BarContainer object of 36 artists>)

# %%
lengths_np = np.array(lengths)

# %%
lengths_np.argmax()
# Out:
# np.int64(4784)

# %%
plt.hist(lengths,bins=5)
# Out:
# (array([  13.,   11.,  397., 5407.,   10.]),
#  array([ 3. ,  9.6, 16.2, 22.8, 29.4, 36. ]),
#  <BarContainer object of 5 artists>)

# %%
d = get_datetime_data(447)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 d = get_datetime_data(447)
#
# Cell In[99], line 11, in get_datetime_data(index)
#       9 dt_list = []
#      10 for hour in range(len(hourly_temp)):
# ---> 11     dt = datetime.strptime(f'{date_string} {hour}', '%Y%m%d %H')
#      12     dt_list.append(dt)
#      14 hourly_temp_np = np.array(hourly_temp, np.float32)
#
# File /usr/lib/python3.12/_strptime.py:554, in _strptime_datetime(cls, data_string, format)
#     551 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     552     """Return a class cls instance based on the input string and the
#     553     format string."""
# --> 554     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     555     tzname, gmtoff = tt[-2:]
#     556     args = tt[:6] + (fraction,)
#
# File /usr/lib/python3.12/_strptime.py:336, in _strptime(data_string, format)
#     333     raise ValueError("time data %r does not match format %r" %
#     334                      (data_string, format))
#     335 if len(data_string) != found.end():
# --> 336     raise ValueError("unconverted data remains: %s" %
#     337                       data_string[found.end():])
#     339 iso_year = year = None
#     340 month = day = 1
#
# ValueError: unconverted data remains: 4

# %%
data_datetime = []

for day in range(len(df)):
    try:
        data = get_datetime_data(day)
        data_datetime.append(data)
    except Exception as e:
        print(day)
        print(e)
# Out:
# 120
# cannot access local variable 'dt_list' where it is not associated with a value
# 124
# cannot access local variable 'dt_list' where it is not associated with a value
# 129
# cannot access local variable 'dt_list' where it is not associated with a value
# 196
# cannot access local variable 'dt_list' where it is not associated with a value
# 224
# cannot access local variable 'dt_list' where it is not associated with a value
# 343
# cannot access local variable 'dt_list' where it is not associated with a value
# 366
# cannot access local variable 'dt_list' where it is not associated with a value
# 369
# cannot access local variable 'dt_list' where it is not associated with a value
# 467
# cannot access local variable 'dt_list' where it is not associated with a value
# 530
# cannot access local variable 'dt_list' where it is not associated with a value
# 587
# cannot access local variable 'dt_list' where it is not associated with a value
# 720
# cannot access local variable 'dt_list' where it is not associated with a value
# 721
# cannot access local variable 'dt_list' where it is not associated with a value
# 788
# cannot access local variable 'dt_list' where it is not associated with a value
# 791
# cannot access local variable 'dt_list' where it is not associated with a value
# 1244
# cannot access local variable 'dt_list' where it is not associated with a value
# 1245
# cannot access local variable 'dt_list' where it is not associated with a value
# 1305
# cannot access local variable 'dt_list' where it is not associated with a value
# 1323
# cannot access local variable 'dt_list' where it is not associated with a value
# 1324
# cannot access local variable 'dt_list' where it is not associated with a value
# 1325
# cannot access local variable 'dt_list' where it is not associated with a value
# 1586
# cannot access local variable 'dt_list' where it is not associated with a value
# 1683
# cannot access local variable 'dt_list' where it is not associated with a value
# 1729
# cannot access local variable 'dt_list' where it is not associated with a value
# 1995
# cannot access local variable 'dt_list' where it is not associated with a value
# 2230
# cannot access local variable 'dt_list' where it is not associated with a value
# 2510
# cannot access local variable 'dt_list' where it is not associated with a value
# 2890
# cannot access local variable 'dt_list' where it is not associated with a value
# 3128
# cannot access local variable 'dt_list' where it is not associated with a value
# 3142
# cannot access local variable 'dt_list' where it is not associated with a value
# 3156
# cannot access local variable 'dt_list' where it is not associated with a value
# 3204
# cannot access local variable 'dt_list' where it is not associated with a value
# 3235
# cannot access local variable 'dt_list' where it is not associated with a value
# 3617
# cannot access local variable 'dt_list' where it is not associated with a value
# 3938
# cannot access local variable 'dt_list' where it is not associated with a value
# 3962
# cannot access local variable 'dt_list' where it is not associated with a value
# 3963
# cannot access local variable 'dt_list' where it is not associated with a value
# 3972
# cannot access local variable 'dt_list' where it is not associated with a value
# 3974
# cannot access local variable 'dt_list' where it is not associated with a value
# 4287
# cannot access local variable 'dt_list' where it is not associated with a value
# 4394
# cannot access local variable 'dt_list' where it is not associated with a value
# 4612
# cannot access local variable 'dt_list' where it is not associated with a value
# 4757
# cannot access local variable 'dt_list' where it is not associated with a value
# 4996
# cannot access local variable 'dt_list' where it is not associated with a value
# 5837
# cannot access local variable 'dt_list' where it is not associated with a value

# %%
plt.plot(d['Datetime'], d['Wind Speed'])
plt.show()

# %%
d['Datetime'][0]
# Out:
# datetime.datetime(2014, 7, 11, 0, 0)

# %%
d
# Out:
# {'Datetime': [datetime.datetime(2014, 7, 11, 0, 0),
#   datetime.datetime(2014, 7, 11, 1, 0),
#   datetime.datetime(2014, 7, 11, 2, 0),
#   datetime.datetime(2014, 7, 11, 3, 0),
#   datetime.datetime(2014, 7, 11, 4, 0),
#   datetime.datetime(2014, 7, 11, 5, 0),
#   datetime.datetime(2014, 7, 11, 6, 0),
#   datetime.datetime(2014, 7, 11, 7, 0),
#   datetime.datetime(2014, 7, 11, 8, 0),
#   datetime.datetime(2014, 7, 11, 9, 0),
#   datetime.datetime(2014, 7, 11, 10, 0),
#   datetime.datetime(2014, 7, 11, 11, 0),
#   datetime.datetime(2014, 7, 11, 12, 0),
#   datetime.datetime(2014, 7, 11, 13, 0),
#   datetime.datetime(2014, 7, 11, 14, 0),
#   datetime.datetime(2014, 7, 11, 15, 0),
#   datetime.datetime(2014, 7, 11, 16, 0),
#   datetime.datetime(2014, 7, 11, 17, 0),
#   datetime.datetime(2014, 7, 11, 18, 0),
#   datetime.datetime(2014, 7, 11, 19, 0),
#   datetime.datetime(2014, 7, 11, 20, 0),
#   datetime.datetime(2014, 7, 11, 21, 0),
#   datetime.datetime(2014, 7, 11, 22, 0)],
#  'Temperature': array([25.      , 25.      , 23.88889 , 23.88889 , 23.88889 , 23.88889 ,
#         25.      , 26.11111 , 27.222221, 27.777779, 28.88889 , 30.      ,
#         31.11111 , 32.77778 , 32.77778 , 32.22222 , 32.22222 , 31.11111 ,
#         30.      , 30.      , 27.222221, 26.11111 , 26.11111 ],
#        dtype=float32),
#  'Condiction': ['Fair',
#   'Fair',
#   'Fair',
#   'Haze',
#   'Haze',
#   'Haze',
#   'Haze',
#   'Haze',
#   'Haze',
#   'Haze',
#   'Fair',
#   'Fair',
#   'Haze',
#   'Haze',
#   'Fair',
#   'Fair',
#   'Fair',
#   'Haze',
#   'Haze',
#   'Fair',
#   'Fair',
#   'Fair',
#   'Fair'],
#  'Wind Direction': array([300., 290., 290., 260., 250., 260., 270., 260., 270., 250., 230.,
#         240., 260., 290., 330., 300., 300., 300., 290., 290., 300., 340.,
#         350.], dtype=float32),
#  'Wind Speed': array([ 7.,  9.,  8.,  6.,  6.,  6.,  8., 12., 10., 10.,  8., 10., 14.,
#         14., 12., 13., 14., 14., 16.,  9.,  7.,  7.,  5.], dtype=float32)}
